# %%
import pandas as pd

#df = pd.read_csv (r'C:\Users\Farouk\Desktop\prediction\dataset_user_data.csv')
#print (df)

data = pd.read_csv (r'C:\Users\Farouk\Desktop\prediction\dataset_user_data(opinpos_event).csv')
print (data)
df = pd.DataFrame(data, columns= ['opinion_positive','event_participation'])
print (df)
# Out:
#       opinion_positive  event_participation
# 0                   20                    9
# 1                   63                    8
# 2                    9                    1
# 3                   34                    1
# 4                   23                    3
# ...                ...                  ...
# 4995                68                    5
# 4996                47                    0
# 4997                98                    0
# 4998                71                    4
# 4999                12                    3
#
# [5000 rows x 2 columns]
#       opinion_positive  event_participation
# 0                   20                    9
# 1                   63                    8
# 2                    9                    1
# 3                   34                    1
# 4                   23                    3
# ...                ...                  ...
# 4995                68                    5
# 4996                47                    0
# 4997                98                    0
# 4998                71                    4
# 4999                12                    3
#
# [5000 rows x 2 columns]

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20412/3771845804.py in <module>
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
df.isnull().sum()
# Out:
# opinion_positive       0
# event_participation    0
# dtype: int64

# %%
df.shape
# Out:
# (5001, 2)

# %%
#Plot opinion_positive vs event_participation............
x1 = df.iloc[:, 0].values
y1 = df.iloc[:, 1].values
plt.scatter(x1,y1,color='Orange',s=50)
plt.xlabel('UserID')
plt.ylabel('Purchased')
plt.title('opinion_positive vs event_participation')
plt.show()

# %%
# Import library
import pandas  as pd #Data manipulation
import numpy as np #Data manipulation
import matplotlib.pyplot as plt # Visualization
import seaborn as sns #Visualization
plt.rcParams['figure.figsize'] = [8,5]
plt.rcParams['font.size'] =14
plt.rcParams['font.weight']= 'bold'
plt.style.use('seaborn-whitegrid')

# %%
# Import dataset
#path ='dataset/'
print('\nNumber of rows and columns in the data set: ',df.shape)
print('')
# Out:
# Number of rows and columns in the data set:  (5001, 2)

# %%
sns.lmplot(x='opinion_positive',y='event_participation',data=df,aspect=2,height=6)
plt.xlabel('opinion_positive')
plt.ylabel('event_participation')
plt.title('opinion_positive Vs event_participation');
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5372/1878817398.py in <module>
# ----> 1 sns.lmplot(x='opinion_positive',y='event_participation',data=df,aspect=2,height=6)
#       2 plt.xlabel('opinion_positive')
#       3 plt.ylabel('event_participation')
#       4 plt.title('opinion_positive Vs event_participation');
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws, size)
#     632         ax.autoscale_view(scaley=False)
#     633
# --> 634     facets.map_dataframe(update_datalim, x=x, y=y)
#     635
#     636     # Draw the regression plot on each facet
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     775
#     776             # Draw the plot
# --> 777             self._facet_plot(func, ax, args, kwargs)
#     778
#     779         # For axis labels, prefer to use positional args for backcompat
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     804             plot_args = []
#     805             plot_kwargs["ax"] = ax
# --> 806         func(*plot_args, **plot_kwargs)
#     807
#     808         # Sort out the supporting information
#
# ~\anaconda3\lib\site-packages\seaborn\regression.py in update_datalim(data, x, y, ax, **kws)
#     628
#     629     def update_datalim(data, x, y, ax, **kws):
# --> 630         xys = np.asarray(data[[x, y]]).astype(float)
#     631         ax.update_datalim(xys, updatey=False)
#     632         ax.autoscale_view(scaley=False)
#
# ValueError: could not convert string to float: 'opinion_negative'
